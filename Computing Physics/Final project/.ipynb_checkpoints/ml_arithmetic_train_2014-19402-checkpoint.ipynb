# %%
#Generating Data for Training and Test
import numpy as np

N = 10000
a_A = np.array([i/1. for i in range(N)])+10*np.random.rand(N)
a_B = np.array([i/1. for i in range(N)])+10*np.random.rand(N)
temp1, temp2 = [], []

for i in range(N):
    temp1.append([a_A[i],a_B[i],a_A[i]+a_B[i]]) # data for add : [A,B,A+B]
    temp2.append([a_A[i],a_B[i],a_A[i]*a_B[i]]) # data for multiply : [A,B,A*B]

data_madd = np.array(temp1)
data_mmul = np.array(temp2)

np.save('datatrain_madd.npy', data_madd)
np.save('datatrain_mmul.npy', data_mmul)
    
arr_A = 2*np.random.randn(N)+1
arr_B = 2*np.random.randn(N)+1

A = 10**(arr_A) # A data
B = 10**(arr_B) # B data

for i in range(N):
    if (arr_A[i] <= 4 and arr_A[i] >= -4) and (arr_B[i] <= 4 and arr_B[i] >= -4):
        temp1.append([A[i],B[i],A[i]+B[i]]) # data for add : [A,B,A+B]
        temp2.append([A[i],B[i],A[i]*B[i]]) # data for multiply : [A,B,A*B]

data_madd = np.array(temp1)
data_mmul = np.array(temp2)

np.save('datatest_madd.npy', data_madd)
np.save('datatest_mmul.npy', data_mmul)



#data3 = np.load('my_data.npy') # 데이터 로드. @파일명

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from itertools import cycle, islice
from time import sleep
import sys
import myNN

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

data_madd = np.load('datatrain_madd.npy') #load data for add_train
data_mmul = np.load('datatrain_mmul.npy') #load data for mul_train

testdata_madd = np.load('datatest_madd.npy') #load data for add_test
testdata_mmul = np.load('datatest_mmul.npy') #load data for mul_test

#Set model structure and learning rate
model_str = np.array(['2:identity|'+'2:identity|'+'1:identity', \
             '2:identity|'+'2:log|'+'2:identity|'+'2:exp|'+'1:identity'])
lr = np.array([0.001, 0.001])
name_tag = np.array(['add_lr'+str(lr[0]), 'mul_lr'+str(lr[1])])


#Call myNN class
madd = myNN.madd(model_structure=model_str[0], \
                     model_nametag=name_tag[0], \
                     learning_rate=lr[0], \
                     encoding='float')

# 훈련 준비
data_type=None # None
encoding='float' #'integer' # 'float'

# 훈련 & 테스트 데이터 준비
# n_data_tot=len(training_data_list)
n_data_max=10000  # 훈련에 사용할 데이터 갯수 (max = 10000)
n_data_test=2000  # 테스트에 사용할 테이터 갯수 (10000 - n_data_max)

## 훈련 데이터
training_data_list = data_madd[:n_data_max]

## 테스트 데이터
test_data_list = testdata_madd[-n_data_test:]

# 최대학습주기 설정
epochs = 100 #10000
dn_data = int(n_data_max/20)

# 설정된 최대학습주기동안 훈련

for e in range(epochs):

    id_data = 0
    
    for data in training_data_list:
        
        # 프로세스 게이지
        id_data += 1
        if (id_data%dn_data==0):
            sys.stdout.write('\r')
            sys.stdout.write(' [%-20s] %d%%' % ( '='*(id_data//dn_data), 5*(id_data//dn_data)))
            sys.stdout.flush()
            sleep(0.25)
        
        # 입력/지도 데이터 가공 
        input_list = data[:2] #np.asfarray(all_values[1:])
        target_origin = data[2]
        target_list = np.zeros(1)
        target_list[0] = data[2]
        
        madd.train(input_list, target_list)
        
        pass

    #열번마다 정확도와 평균 에러를 표시해주면서, nnfactory안에 error를 기록해놓습니다.
    if (e%10==0):
        print (' --------------------------------------')
        print(' * epoch = {}'.format(e+1))
        print(' > 훈련 샘플에 대한 성능 (정확도 & 평균에러) ')
        #mynn.check_accuracy_error에서 현재 정확도와 평균에러를 return하도록 설정해주어 이를 training_err로 받은 모습입니다.
        madd.check_accuracy_error(training_data_list, 0, n_data_max-1, data_type=None)
        print('')
        print(' > 테스트 샘플에 대한 성능 (정확도 & 평균에러) ')
        #마찬가지로, mynn.check_accuracy_error에서 현재 정확도와 평균에러를 return하도록 설정해주어 이를 test_err로 받은 모습입니다.
        madd.check_accuracy_error(test_data_list, 0, n_data_test-1, data_type=None)
    
    pass
# Out:
#  * 다음과 같은 구조의 다층퍼셉트론 연결이 초기화 되었습니다 *
#
#  > 모델이름 = add_lr0.001
#  > 총 층수 (입력 + 은닉(s) + 출력) =  3
#  > 각 층에서의 노드수 =  [2, 2, 1]
#  > 각 층에서의 활성화 함수 =  ['identity', 'identity', 'identity']
#  > 학습률(Learning Rate) =  0.001
#  > 지도라벨 인코딩 방식 =  float
#  [====================] 100% --------------------------------------
#  * epoch = 1
#  > 훈련 샘플에 대한 성능 (정확도 & 평균에러)
#
#  * 현재 평균에러 =  inf
#
#  > 테스트 샘플에 대한 성능 (정확도 & 평균에러)
#
#  * 현재 평균에러 =  inf
#  [=========           ] 45%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-e3a79e7e62fc> in <module>()
#      59             sys.stdout.write(' [%-20s] %d%%' % ( '='*(id_data//dn_data), 5*(id_data//dn_data)))
#      60             sys.stdout.flush()
# ---> 61             sleep(0.25)
#      62
#      63         # 입력/지도 데이터 가공
#
# KeyboardInterrupt:

# %%
mmul = myNN.mmul(model_structure=model_str[1], \
                     model_nametag=name_tag[1], \
                     learning_rate=lr[1], \
                     encoding='float',optimizer = 'momentum')

# 훈련 준비
data_type=None # None
encoding='float' #'integer' # 'float'

# 훈련 & 테스트 데이터 준비
# n_data_tot=len(training_data_list)
n_data_max=10000  # 훈련에 사용할 데이터 갯수 (max = 10000)
n_data_test=2000  # 테스트에 사용할 테이터 갯수 (10000 - n_data_max)

## 훈련 데이터
training_data_list = data_madd[:n_data_max]

## 테스트 데이터
test_data_list = testdata_madd[-n_data_test:]

# 최대학습주기 설정
epochs = 100 #10000
dn_data = int(n_data_max/20)

# 설정된 최대학습주기동안 훈련

for e in range(epochs):

    id_data = 0
    
    for data in training_data_list:
        
        # 프로세스 게이지
        id_data += 1
        if (id_data%dn_data==0):
            sys.stdout.write('\r')
            sys.stdout.write(' [%-20s] %d%%' % ( '='*(id_data//dn_data), 5*(id_data//dn_data)))
            sys.stdout.flush()
            sleep(0.25)
        
        # 입력/지도 데이터 가공 
        input_list = data[:2] #np.asfarray(all_values[1:])
        target_origin = data[2]
        target_list = np.zeros(1)
        target_list[0] = data[2]
        
        mmul.train(input_list, target_list)
        
        pass

    #열번마다 정확도와 평균 에러를 표시해주면서, nnfactory안에 error를 기록해놓습니다.
    if (e%10==0):
        print (' --------------------------------------')
        print(' * epoch = {}'.format(e+1))
        print(' > 훈련 샘플에 대한 성능 (정확도 & 평균에러) ')
        #mynn.check_accuracy_error에서 현재 정확도와 평균에러를 return하도록 설정해주어 이를 training_err로 받은 모습입니다.
        mmul.check_accuracy_error(training_data_list, 0, n_data_max-1, data_type=None)
        print('')
        print(' > 테스트 샘플에 대한 성능 (정확도 & 평균에러) ')
        #마찬가지로, mynn.check_accuracy_error에서 현재 정확도와 평균에러를 return하도록 설정해주어 이를 test_err로 받은 모습입니다.
        mmul.check_accuracy_error(test_data_list, 0, n_data_test-1, data_type=None)
    
    pass
# Out:
#  * 다음과 같은 구조의 다층퍼셉트론 연결이 초기화 되었습니다 *
#
#  > 모델이름 = mul_lr0.001
#  > 총 층수 (입력 + 은닉(s) + 출력) =  5
#  > 각 층에서의 노드수 =  [2, 2, 2, 2, 1]
#  > 각 층에서의 활성화 함수 =  ['identity', 'log', 'identity', 'exp', 'identity']
#  > 학습률(Learning Rate) =  0.001
#  > 지도라벨 인코딩 방식 =  float
# [5.46675904 4.02896592 9.49572496]
# [5.46675904 4.02896592]
# 9.495724962059963
# [9.49572496]
# [[5.46675904]
#  [4.02896592]] f[i] 0
# [[0.70710678 0.70710678]
#  [0.70710678 0.70710678]] W[i-1] 1
# [[1.9042681]
#  [1.9042681]] f[i] 1
# [[0.70710678 0.70710678]
#  [0.70710678 0.70710678]] W[i-1] 2
# [[2.69304178]
#  [2.69304178]] f[i] 2
# [[0.70710678 0.70710678]
#  [0.70710678 0.70710678]] W[i-1] 3
# [[45.08439628]
#  [45.08439628]] f[i] 3
# [[0.70710678 0.70710678]] W[i-1] 4
# [[63.75896467]] f[i] 4
# [[9.49572496]] target_y
# [[54.26323971]] delta 4
# [[1729.88399154]
#  [1729.88399154]] delta 3
# [[2446.42540217]
#  [2446.42540217]] delta 2
# [[515.26879979]
#  [515.26879979]] delta 1
#
# [3.97163573 3.91946344 7.89109916]
# [3.97163573 3.91946344]
# 7.8910991639040065
# [7.89109916]
# [[3.97163573]
#  [3.91946344]] f[i] 0
# [[-2.10974359 -1.36889365]
#  [-2.10974359 -1.36889365]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[-3.95154308 -3.95154308]
#  [-3.95154308 -3.95154308]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[-3.95154308 -3.95154308]
#  [-3.95154308 -3.95154308]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[-1.73931862 -1.73931862]] W[i-1] 4
# [[nan]] f[i] 4
# [[7.89109916]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 8.40290344  2.79959867 11.20250211]
# [8.40290344 2.79959867]
# 11.20250210875969
# [11.20250211]
# [[8.40290344]
#  [2.79959867]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[11.20250211]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [12.8479087   8.15208415 20.99999286]
# [12.8479087   8.15208415]
# 20.999992856435064
# [20.99999286]
# [[12.8479087 ]
#  [ 8.15208415]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[20.99999286]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 7.63879259  5.71870969 13.35750228]
# [7.63879259 5.71870969]
# 13.357502283124965
# [13.35750228]
# [[7.63879259]
#  [5.71870969]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[13.35750228]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [11.83299774 12.55544326 24.388441  ]
# [11.83299774 12.55544326]
# 24.388441003449074
# [24.388441]
# [[11.83299774]
#  [12.55544326]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[24.388441]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 7.16716523  9.140744   16.30790923]
# [7.16716523 9.140744  ]
# 16.307909226969407
# [16.30790923]
# [[7.16716523]
#  [9.140744  ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[16.30790923]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [14.97023049 15.77033748 30.74056797]
# [14.97023049 15.77033748]
# 30.740567972924833
# [30.74056797]
# [[14.97023049]
#  [15.77033748]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[30.74056797]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [14.97718035 10.50021361 25.47739397]
# [14.97718035 10.50021361]
# 25.47739396508799
# [25.47739397]
# [[14.97718035]
#  [10.50021361]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[25.47739397]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [12.46698066 13.24063518 25.70761584]
# [12.46698066 13.24063518]
# 25.70761583757576
# [25.70761584]
# [[12.46698066]
#  [13.24063518]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[25.70761584]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [19.04223718 18.64745847 37.68969565]
# [19.04223718 18.64745847]
# 37.68969564797328
# [37.68969565]
# [[19.04223718]
#  [18.64745847]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[37.68969565]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [15.02820031 16.67300089 31.7012012 ]
# [15.02820031 16.67300089]
# 31.701201196233356
# [31.7012012]
# [[15.02820031]
#  [16.67300089]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[31.7012012]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [19.76144435 20.6721879  40.43363226]
# [19.76144435 20.6721879 ]
# 40.433632257896754
# [40.43363226]
# [[19.76144435]
#  [20.6721879 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[40.43363226]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [17.40354181 22.54914097 39.95268278]
# [17.40354181 22.54914097]
# 39.95268278231808
# [39.95268278]
# [[17.40354181]
#  [22.54914097]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[39.95268278]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [22.13621501 20.99923624 43.13545125]
# [22.13621501 20.99923624]
# 43.135451251419006
# [43.13545125]
# [[22.13621501]
#  [20.99923624]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[43.13545125]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [19.9290403  20.47654334 40.40558363]
# [19.9290403  20.47654334]
# 40.40558363398107
# [40.40558363]
# [[19.9290403 ]
#  [20.47654334]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[40.40558363]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [19.88067056 25.55149187 45.43216243]
# [19.88067056 25.55149187]
# 45.43216243250767
# [45.43216243]
# [[19.88067056]
#  [25.55149187]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[45.43216243]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [21.56121726 22.45285703 44.01407429]
# [21.56121726 22.45285703]
# 44.014074291215714
# [44.01407429]
# [[21.56121726]
#  [22.45285703]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[44.01407429]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [25.89468027 22.53655069 48.43123096]
# [25.89468027 22.53655069]
# 48.431230960111776
# [48.43123096]
# [[25.89468027]
#  [22.53655069]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[48.43123096]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [20.30731948 25.25269724 45.56001672]
# [20.30731948 25.25269724]
# 45.560016715995616
# [45.56001672]
# [[20.30731948]
#  [25.25269724]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[45.56001672]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [28.74161448 22.97493455 51.71654903]
# [28.74161448 22.97493455]
# 51.71654903413526
# [51.71654903]
# [[28.74161448]
#  [22.97493455]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[51.71654903]] target_y
# [[nan]]
# /mnt/c/Users/박혜민/Desktop/18년/2학기/CP/Final project/myNN.py:402: RuntimeWarning: invalid value encountered in log
#   return np.log(a)
#  delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [23.30262142 22.89100309 46.19362451]
# [23.30262142 22.89100309]
# 46.19362451178014
# [46.19362451]
# [[23.30262142]
#  [22.89100309]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[46.19362451]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [22.4469068  23.61160968 46.05851648]
# [22.4469068  23.61160968]
# 46.058516483483004
# [46.05851648]
# [[22.4469068 ]
#  [23.61160968]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[46.05851648]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [31.26989751 32.49266088 63.76255839]
# [31.26989751 32.49266088]
# 63.762558392760084
# [63.76255839]
# [[31.26989751]
#  [32.49266088]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[63.76255839]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [33.3266667  27.78917494 61.11584164]
# [33.3266667  27.78917494]
# 61.115841635590364
# [61.11584164]
# [[33.3266667 ]
#  [27.78917494]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[61.11584164]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [27.40503887 25.20073479 52.60577366]
# [27.40503887 25.20073479]
# 52.60577365539852
# [52.60577366]
# [[27.40503887]
#  [25.20073479]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[52.60577366]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [34.87573636 32.25921005 67.13494641]
# [34.87573636 32.25921005]
# 67.13494640803077
# [67.13494641]
# [[34.87573636]
#  [32.25921005]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[67.13494641]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [29.13536517 36.16723675 65.30260192]
# [29.13536517 36.16723675]
# 65.30260191660767
# [65.30260192]
# [[29.13536517]
#  [36.16723675]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[65.30260192]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [35.00331517 29.86871397 64.87202913]
# [35.00331517 29.86871397]
# 64.87202913202002
# [64.87202913]
# [[35.00331517]
#  [29.86871397]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[64.87202913]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [38.60771749 32.00229661 70.61001409]
# [38.60771749 32.00229661]
# 70.61001409483453
# [70.61001409]
# [[38.60771749]
#  [32.00229661]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[70.61001409]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [34.97013102 31.6429004  66.61303142]
# [34.97013102 31.6429004 ]
# 66.61303142050163
# [66.61303142]
# [[34.97013102]
#  [31.6429004 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[66.61303142]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [34.75310697 37.63734042 72.39044739]
# [34.75310697 37.63734042]
# 72.39044738917704
# [72.39044739]
# [[34.75310697]
#  [37.63734042]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[72.39044739]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [34.54388186 39.46830698 74.01218884]
# [34.54388186 39.46830698]
# 74.01218884123733
# [74.01218884]
# [[34.54388186]
#  [39.46830698]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[74.01218884]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [36.78069078 34.72220392 71.50289471]
# [36.78069078 34.72220392]
# 71.50289470609877
# [71.50289471]
# [[36.78069078]
#  [34.72220392]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[71.50289471]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [43.28047309 40.2893871  83.56986019]
# [43.28047309 40.2893871 ]
# 83.56986019271503
# [83.56986019]
# [[43.28047309]
#  [40.2893871 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[83.56986019]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [44.9415363  43.29964162 88.24117792]
# [44.9415363  43.29964162]
# 88.24117792193192
# [88.24117792]
# [[44.9415363 ]
#  [43.29964162]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[88.24117792]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [39.55667617 37.19071379 76.74738995]
# [39.55667617 37.19071379]
# 76.7473899540029
# [76.74738995]
# [[39.55667617]
#  [37.19071379]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[76.74738995]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [41.87749017 44.73241311 86.60990327]
# [41.87749017 44.73241311]
# 86.60990327277763
# [86.60990327]
# [[41.87749017]
#  [44.73241311]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[86.60990327]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [45.06164245 42.41277837 87.47442082]
# [45.06164245 42.41277837]
# 87.47442082377657
# [87.47442082]
# [[45.06164245]
#  [42.41277837]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[87.47442082]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [47.81866221 48.67237331 96.49103552]
# [47.81866221 48.67237331]
# 96.49103552119837
# [96.49103552]
# [[47.81866221]
#  [48.67237331]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[96.49103552]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [44.3197476  42.21204198 86.53178958]
# [44.3197476  42.21204198]
# 86.53178958431262
# [86.53178958]
# [[44.3197476 ]
#  [42.21204198]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[86.53178958]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [42.67925901 47.5326834  90.21194241]
# [42.67925901 47.5326834 ]
# 90.21194241324321
# [90.21194241]
# [[42.67925901]
#  [47.5326834 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[90.21194241]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [48.89007876 46.38175466 95.27183342]
# [48.89007876 46.38175466]
# 95.27183341602839
# [95.27183342]
# [[48.89007876]
#  [46.38175466]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[95.27183342]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [45.45134343 52.45133057 97.90267399]
# [45.45134343 52.45133057]
# 97.90267399445989
# [97.90267399]
# [[45.45134343]
#  [52.45133057]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[97.90267399]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [46.72303754 47.70906919 94.43210672]
# [46.72303754 47.70906919]
# 94.43210672283774
# [94.43210672]
# [[46.72303754]
#  [47.70906919]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[94.43210672]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 46.4032437   54.42793063 100.83117432]
# [46.4032437  54.42793063]
# 100.83117432361973
# [100.83117432]
# [[46.4032437 ]
#  [54.42793063]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[100.83117432]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 51.40395721  50.67871062 102.08266784]
# [51.40395721 50.67871062]
# 102.0826678362537
# [102.08266784]
# [[51.40395721]
#  [50.67871062]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[102.08266784]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 52.45800363  51.00101595 103.45901959]
# [52.45800363 51.00101595]
# 103.45901958520203
# [103.45901959]
# [[52.45800363]
#  [51.00101595]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[103.45901959]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 53.80487216  56.35556257 110.16043473]
# [53.80487216 56.35556257]
# 110.16043473439854
# [110.16043473]
# [[53.80487216]
#  [56.35556257]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[110.16043473]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 50.06630396  51.35988109 101.42618506]
# [50.06630396 51.35988109]
# 101.42618505582521
# [101.42618506]
# [[50.06630396]
#  [51.35988109]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[101.42618506]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 50.19608557  55.82116317 106.01724875]
# [50.19608557 55.82116317]
# 106.01724874588793
# [106.01724875]
# [[50.19608557]
#  [55.82116317]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[106.01724875]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 60.53232402  59.43594749 119.96827151]
# [60.53232402 59.43594749]
# 119.96827151246471
# [119.96827151]
# [[60.53232402]
#  [59.43594749]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[119.96827151]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 54.2605625   56.15740426 110.41796676]
# [54.2605625  56.15740426]
# 110.41796676379447
# [110.41796676]
# [[54.2605625 ]
#  [56.15740426]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[110.41796676]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 59.28499674  57.29398046 116.5789772 ]
# [59.28499674 57.29398046]
# 116.57897719638456
# [116.5789772]
# [[59.28499674]
#  [57.29398046]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[116.5789772]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 55.36978409  57.89530716 113.26509124]
# [55.36978409 57.89530716]
# 113.2650912424172
# [113.26509124]
# [[55.36978409]
#  [57.89530716]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[113.26509124]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 60.97330177  64.23045689 125.20375867]
# [60.97330177 64.23045689]
# 125.20375866616942
# [125.20375867]
# [[60.97330177]
#  [64.23045689]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[125.20375867]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 57.02760101  63.43972094 120.46732196]
# [57.02760101 63.43972094]
# 120.46732195542724
# [120.46732196]
# [[57.02760101]
#  [63.43972094]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[120.46732196]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 66.89632771  59.68154917 126.57787689]
# [66.89632771 59.68154917]
# 126.57787688510136
# [126.57787689]
# [[66.89632771]
#  [59.68154917]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[126.57787689]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 59.48910663  61.23164412 120.72075075]
# [59.48910663 61.23164412]
# 120.72075074630675
# [120.72075075]
# [[59.48910663]
#  [61.23164412]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[120.72075075]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 60.8703903   66.97915269 127.84954299]
# [60.8703903  66.97915269]
# 127.84954298870649
# [127.84954299]
# [[60.8703903 ]
#  [66.97915269]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[127.84954299]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 65.80412717  67.2017395  133.00586667]
# [65.80412717 67.2017395 ]
# 133.0058666680644
# [133.00586667]
# [[65.80412717]
#  [67.2017395 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[133.00586667]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 62.91540963  68.91051763 131.82592725]
# [62.91540963 68.91051763]
# 131.82592725255034
# [131.82592725]
# [[62.91540963]
#  [68.91051763]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[131.82592725]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 63.89942715  62.56618253 126.46560968]
# [63.89942715 62.56618253]
# 126.46560967889168
# [126.46560968]
# [[63.89942715]
#  [62.56618253]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[126.46560968]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 64.79352595  71.59842451 136.39195046]
# [64.79352595 71.59842451]
# 136.3919504643544
# [136.39195046]
# [[64.79352595]
#  [71.59842451]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[136.39195046]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 65.34325528  68.98382098 134.32707627]
# [65.34325528 68.98382098]
# 134.32707626639325
# [134.32707627]
# [[65.34325528]
#  [68.98382098]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[134.32707627]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 73.32965572  69.09314831 142.42280402]
# [73.32965572 69.09314831]
# 142.42280402322473
# [142.42280402]
# [[73.32965572]
#  [69.09314831]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[142.42280402]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 67.27160087  73.42980564 140.70140651]
# [67.27160087 73.42980564]
# 140.7014065117379
# [140.70140651]
# [[67.27160087]
#  [73.42980564]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[140.70140651]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 69.39254818  69.62229523 139.01484341]
# [69.39254818 69.62229523]
# 139.01484341247618
# [139.01484341]
# [[69.39254818]
#  [69.62229523]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[139.01484341]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 69.82606412  70.52247291 140.34853703]
# [69.82606412 70.52247291]
# 140.34853702987698
# [140.34853703]
# [[69.82606412]
#  [70.52247291]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[140.34853703]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 69.2891664   77.27992769 146.5690941 ]
# [69.2891664  77.27992769]
# 146.56909409703243
# [146.5690941]
# [[69.2891664 ]
#  [77.27992769]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[146.5690941]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 71.83446099  72.44382884 144.27828982]
# [71.83446099 72.44382884]
# 144.27828982434414
# [144.27828982]
# [[71.83446099]
#  [72.44382884]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[144.27828982]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 79.65461424  71.55029507 151.20490931]
# [79.65461424 71.55029507]
# 151.2049093104167
# [151.20490931]
# [[79.65461424]
#  [71.55029507]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[151.20490931]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 81.49281345  81.48052762 162.97334106]
# [81.49281345 81.48052762]
# 162.97334106182626
# [162.97334106]
# [[81.49281345]
#  [81.48052762]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[162.97334106]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 73.14614671  79.86589145 153.01203816]
# [73.14614671 79.86589145]
# 153.01203816184378
# [153.01203816]
# [[73.14614671]
#  [79.86589145]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[153.01203816]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 80.9857423   80.83443942 161.82018173]
# [80.9857423  80.83443942]
# 161.82018172719575
# [161.82018173]
# [[80.9857423 ]
#  [80.83443942]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[161.82018173]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 77.14071061  77.73242414 154.87313475]
# [77.14071061 77.73242414]
# 154.87313475001034
# [154.87313475]
# [[77.14071061]
#  [77.73242414]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[154.87313475]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 81.39697914  79.50975145 160.90673059]
# [81.39697914 79.50975145]
# 160.90673059103523
# [160.90673059]
# [[81.39697914]
#  [79.50975145]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[160.90673059]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 77.15028212  86.12826659 163.27854871]
# [77.15028212 86.12826659]
# 163.27854870627652
# [163.27854871]
# [[77.15028212]
#  [86.12826659]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[163.27854871]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 87.42410169  86.68383115 174.10793284]
# [87.42410169 86.68383115]
# 174.1079328432064
# [174.10793284]
# [[87.42410169]
#  [86.68383115]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[174.10793284]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 86.03065724  85.37157342 171.40223067]
# [86.03065724 85.37157342]
# 171.4022306674828
# [171.40223067]
# [[86.03065724]
#  [85.37157342]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[171.40223067]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 89.43215487  86.55666362 175.98881849]
# [89.43215487 86.55666362]
# 175.98881848989646
# [175.98881849]
# [[89.43215487]
#  [86.55666362]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[175.98881849]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 82.64049383  87.81347029 170.45396412]
# [82.64049383 87.81347029]
# 170.45396412457117
# [170.45396412]
# [[82.64049383]
#  [87.81347029]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[170.45396412]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 87.75423021  87.84054361 175.59477382]
# [87.75423021 87.84054361]
# 175.59477382130538
# [175.59477382]
# [[87.75423021]
#  [87.84054361]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[175.59477382]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 89.8096909   88.73724399 178.54693489]
# [89.8096909  88.73724399]
# 178.54693489040545
# [178.54693489]
# [[89.8096909 ]
#  [88.73724399]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[178.54693489]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 90.98149937  84.19358267 175.17508203]
# [90.98149937 84.19358267]
# 175.17508203199685
# [175.17508203]
# [[90.98149937]
#  [84.19358267]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[175.17508203]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 94.00401966  93.77622047 187.78024013]
# [94.00401966 93.77622047]
# 187.7802401334624
# [187.78024013]
# [[94.00401966]
#  [93.77622047]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[187.78024013]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 90.01942326  86.14143651 176.16085977]
# [90.01942326 86.14143651]
# 176.16085976802788
# [176.16085977]
# [[90.01942326]
#  [86.14143651]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[176.16085977]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 95.60114243  87.69163408 183.29277651]
# [95.60114243 87.69163408]
# 183.2927765086987
# [183.29277651]
# [[95.60114243]
#  [87.69163408]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[183.29277651]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 91.15525345  94.31744044 185.47269389]
# [91.15525345 94.31744044]
# 185.47269388940282
# [185.47269389]
# [[91.15525345]
#  [94.31744044]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[185.47269389]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 93.09996414  92.91190539 186.01186954]
# [93.09996414 92.91190539]
# 186.01186953597045
# [186.01186954]
# [[93.09996414]
#  [92.91190539]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[186.01186954]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 91.87504106  90.41227591 182.28731698]
# [91.87504106 90.41227591]
# 182.287316975001
# [182.28731698]
# [[91.87504106]
#  [90.41227591]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[182.28731698]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 94.65848662  96.64981734 191.30830396]
# [94.65848662 96.64981734]
# 191.3083039624723
# [191.30830396]
# [[94.65848662]
#  [96.64981734]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[191.30830396]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 95.73154645  97.3410759  193.07262235]
# [95.73154645 97.3410759 ]
# 193.0726223519348
# [193.07262235]
# [[95.73154645]
#  [97.3410759 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[193.07262235]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [101.05151831  98.73718304 199.78870135]
# [101.05151831  98.73718304]
# 199.78870135115497
# [199.78870135]
# [[101.05151831]
#  [ 98.73718304]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[199.78870135]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 95.645197    97.98143591 193.6266329 ]
# [95.645197   97.98143591]
# 193.62663290329752
# [193.6266329]
# [[95.645197  ]
#  [97.98143591]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[193.6266329]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [100.5718385   95.70323725 196.27507575]
# [100.5718385   95.70323725]
# 196.2750757480385
# [196.27507575]
# [[100.5718385 ]
#  [ 95.70323725]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[196.27507575]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [101.60202052 100.03597663 201.63799715]
# [101.60202052 100.03597663]
# 201.63799714838876
# [201.63799715]
# [[101.60202052]
#  [100.03597663]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[201.63799715]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [ 98.11984198 102.96061799 201.08045997]
# [ 98.11984198 102.96061799]
# 201.08045997432248
# [201.08045997]
# [[ 98.11984198]
#  [102.96061799]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[201.08045997]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [107.81951832 103.5009184  211.32043672]
# [107.81951832 103.5009184 ]
# 211.32043672433377
# [211.32043672]
# [[107.81951832]
#  [103.5009184 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[211.32043672]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [106.45851887 107.19222266 213.65074154]
# [106.45851887 107.19222266]
# 213.65074153552445
# [213.65074154]
# [[106.45851887]
#  [107.19222266]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[213.65074154]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [104.61062328 107.60995492 212.2205782 ]
# [104.61062328 107.60995492]
# 212.22057820241847
# [212.2205782]
# [[104.61062328]
#  [107.60995492]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[212.2205782]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [101.33924452 110.62529182 211.96453633]
# [101.33924452 110.62529182]
# 211.96453633274496
# [211.96453633]
# [[101.33924452]
#  [110.62529182]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[211.96453633]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [111.61380593 103.98552188 215.59932781]
# [111.61380593 103.98552188]
# 215.59932780983365
# [215.59932781]
# [[111.61380593]
#  [103.98552188]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[215.59932781]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [112.72744753 110.79046285 223.51791038]
# [112.72744753 110.79046285]
# 223.51791037826368
# [223.51791038]
# [[112.72744753]
#  [110.79046285]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[223.51791038]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [113.60307305 112.82335898 226.42643204]
# [113.60307305 112.82335898]
# 226.42643203580286
# [226.42643204]
# [[113.60307305]
#  [112.82335898]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[226.42643204]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [111.4345736  114.50533444 225.93990804]
# [111.4345736  114.50533444]
# 225.93990804259022
# [225.93990804]
# [[111.4345736 ]
#  [114.50533444]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[225.93990804]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
# ...
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3739.50848155]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1867.11900727 1871.94981088 3739.06881815]
# [1867.11900727 1871.94981088]
# 3739.0688181465985
# [3739.06881815]
# [[1867.11900727]
#  [1871.94981088]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3739.06881815]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1873.64887315 1873.59084181 3747.23971497]
# [1873.64887315 1873.59084181]
# 3747.239714967278
# [3747.23971497]
# [[1873.64887315]
#  [1873.59084181]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3747.23971497]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1873.92245588 1873.66559976 3747.58805564]
# [1873.92245588 1873.66559976]
# 3747.5880556418806
# [3747.58805564]
# [[1873.92245588]
#  [1873.66559976]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3747.58805564]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1874.3273507  1870.10384931 3744.43120001]
# [1874.3273507  1870.10384931]
# 3744.4312000080363
# [3744.43120001]
# [[1874.3273507 ]
#  [1870.10384931]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3744.43120001]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1872.81945002 1876.87871029 3749.69816031]
# [1872.81945002 1876.87871029]
# 3749.6981603107442
# [3749.69816031]
# [[1872.81945002]
#  [1876.87871029]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3749.69816031]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1877.38499527 1870.81473188 3748.19972715]
# [1877.38499527 1870.81473188]
# 3748.1997271503765
# [3748.19972715]
# [[1877.38499527]
#  [1870.81473188]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3748.19972715]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1876.4277748  1873.74978697 3750.17756178]
# [1876.4277748  1873.74978697]
# 3750.1775617771227
# [3750.17756178]
# [[1876.4277748 ]
#  [1873.74978697]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3750.17756178]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1880.51394026 1876.23740397 3756.75134422]
# [1880.51394026 1876.23740397]
# 3756.751344224087
# [3756.75134422]
# [[1880.51394026]
#  [1876.23740397]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3756.75134422]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1876.79014905 1881.31591841 3758.10606747]
# [1876.79014905 1881.31591841]
# 3758.106067465208
# [3758.10606747]
# [[1876.79014905]
#  [1881.31591841]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3758.10606747]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1882.48213141 1880.74820891 3763.23034032]
# [1882.48213141 1880.74820891]
# 3763.2303403236765
# [3763.23034032]
# [[1882.48213141]
#  [1880.74820891]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3763.23034032]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1875.39028091 1880.26366858 3755.65394949]
# [1875.39028091 1880.26366858]
# 3755.653949494511
# [3755.65394949]
# [[1875.39028091]
#  [1880.26366858]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3755.65394949]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1879.27838764 1880.41617989 3759.69456753]
# [1879.27838764 1880.41617989]
# 3759.694567526274
# [3759.69456753]
# [[1879.27838764]
#  [1880.41617989]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3759.69456753]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1884.35149715 1878.83272506 3763.18422221]
# [1884.35149715 1878.83272506]
# 3763.1842222100804
# [3763.18422221]
# [[1884.35149715]
#  [1878.83272506]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3763.18422221]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1883.25618962 1887.78751426 3771.04370388]
# [1883.25618962 1887.78751426]
# 3771.0437038781633
# [3771.04370388]
# [[1883.25618962]
#  [1887.78751426]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3771.04370388]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1881.08229408 1884.93260578 3766.01489987]
# [1881.08229408 1884.93260578]
# 3766.01489986634
# [3766.01489987]
# [[1881.08229408]
#  [1884.93260578]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3766.01489987]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1886.24525899 1882.14989613 3768.39515511]
# [1886.24525899 1882.14989613]
# 3768.3951551115324
# [3768.39515511]
# [[1886.24525899]
#  [1882.14989613]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3768.39515511]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1882.46430191 1888.08111243 3770.54541434]
# [1882.46430191 1888.08111243]
# 3770.5454143350516
# [3770.54541434]
# [[1882.46430191]
#  [1888.08111243]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3770.54541434]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1890.48321104 1884.17191884 3774.65512988]
# [1890.48321104 1884.17191884]
# 3774.6551298806553
# [3774.65512988]
# [[1890.48321104]
#  [1884.17191884]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3774.65512988]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1885.76800568 1885.52964876 3771.29765444]
# [1885.76800568 1885.52964876]
# 3771.2976544353673
# [3771.29765444]
# [[1885.76800568]
#  [1885.52964876]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3771.29765444]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1890.77172937 1893.1550168  3783.92674617]
# [1890.77172937 1893.1550168 ]
# 3783.9267461726367
# [3783.92674617]
# [[1890.77172937]
#  [1893.1550168 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3783.92674617]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1892.51131211 1885.89061053 3778.40192264]
# [1892.51131211 1885.89061053]
# 3778.4019226404225
# [3778.40192264]
# [[1892.51131211]
#  [1885.89061053]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3778.40192264]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1886.93427083 1891.10513994 3778.03941077]
# [1886.93427083 1891.10513994]
# 3778.039410769108
# [3778.03941077]
# [[1886.93427083]
#  [1891.10513994]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3778.03941077]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1892.60257425 1891.69094616 3784.29352041]
# [1892.60257425 1891.69094616]
# 3784.2935204115884
# [3784.29352041]
# [[1892.60257425]
#  [1891.69094616]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3784.29352041]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1889.55732892 1895.2761362  3784.83346513]
# [1889.55732892 1895.2761362 ]
# 3784.833465127385
# [3784.83346513]
# [[1889.55732892]
#  [1895.2761362 ]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3784.83346513]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1890.37074472 1898.81642673 3789.18717144]
# [1890.37074472 1898.81642673]
# 3789.1871714436456
# [3789.18717144]
# [[1890.37074472]
#  [1898.81642673]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3789.18717144]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1898.99438359 1895.03686694 3794.03125053]
# [1898.99438359 1895.03686694]
# 3794.0312505333404
# [3794.03125053]
# [[1898.99438359]
#  [1895.03686694]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3794.03125053]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1894.30709724 1898.04350125 3792.35059849]
# [1894.30709724 1898.04350125]
# 3792.350598494223
# [3792.35059849]
# [[1894.30709724]
#  [1898.04350125]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3792.35059849]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1895.42750645 1897.27064966 3792.6981561 ]
# [1895.42750645 1897.27064966]
# 3792.6981561018865
# [3792.6981561]
# [[1895.42750645]
#  [1897.27064966]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3792.6981561]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1902.48719592 1893.41574608 3795.902942  ]
# [1902.48719592 1893.41574608]
# 3795.9029420044
# [3795.902942]
# [[1902.48719592]
#  [1893.41574608]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3795.902942]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1899.54428339 1898.42970972 3797.97399311]
# [1899.54428339 1898.42970972]
# 3797.9739931102476
# [3797.97399311]
# [[1899.54428339]
#  [1898.42970972]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3797.97399311]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1896.44362651 1899.09812467 3795.54175118]
# [1896.44362651 1899.09812467]
# 3795.5417511815413
# [3795.54175118]
# [[1896.44362651]
#  [1899.09812467]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3795.54175118]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
#
# [1903.00894611 1905.86271242 3808.87165853]
# [1903.00894611 1905.86271242]
# 3808.8716585307275
# [3808.87165853]
# [[1903.00894611]
#  [1905.86271242]] f[i] 0
# [[nan nan]
#  [nan nan]] W[i-1] 1
# [[nan]
#  [nan]] f[i] 1
# [[nan nan]
#  [nan nan]] W[i-1] 2
# [[nan]
#  [nan]] f[i] 2
# [[nan nan]
#  [nan nan]] W[i-1] 3
# [[nan]
#  [nan]] f[i] 3
# [[nan nan]] W[i-1] 4
# [[nan]] f[i] 4
# [[3808.87165853]] target_y
# [[nan]] delta 4
# [[nan]
#  [nan]] delta 3
# [[nan]
#  [nan]] delta 2
# [[nan]
#  [nan]] delta 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-2adf62339d62> in <module>()
#      48         print(target_list)
#      49
# ---> 50         mmul.train(input_list, target_list)
#      51
#      52         pass
#
# /mnt/c/Users/박혜민/Desktop/18년/2학기/CP/Final project/myNN.py in train(self, input_list, target_list, error_func)
#     389         self.feedforward(input_list)
#     390
# --> 391         E = self.backpropagate(target_list, error_func)
#     392
#     393         pass
#
# /mnt/c/Users/박혜민/Desktop/18년/2학기/CP/Final project/myNN.py in backpropagate(self, target_list, error_func)
#     353             for i in range(self.n_layers-1, 0, -1):
#     354                 self.W[i-1] += - self.learning_rate * np.matmul(self.delta[i], self.f[i-1].T)
# --> 355                 self.B[i-1] += - self.learning_rate * self.delta[i]
#     356
#     357         if self.optimizer=='momentum':
#
# KeyboardInterrupt:

# %%
#Save madd & mmul model
madd.save_model(fname='madd_2014-19402.npz', nametag='madd_4relu')
mmul.save_model(fname='mmul_2014-19402.npz', nametag='mmul_4relu')

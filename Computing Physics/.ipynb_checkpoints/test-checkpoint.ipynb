# %%
import numpy as np

a = np.random.randn(5,6)
print(a)
print()
b = a.reshape(3,10)
print(b)
print()
c = np.random.randn(6,2)
d = np.dot(a,c)
print(c)
print(c.T)
e = np.array([1,2,3,4])
# Out:
# [[ 1.96755992 -0.95297516  2.1831636   1.05568928  1.29386139  0.89739853]
#  [ 0.17313302  0.5384962   0.16166569  0.92176764 -1.49605658 -0.46209185]
#  [-0.32505144 -1.54145575  0.13001676  0.56783193  0.47006383 -0.93555969]
#  [ 0.3777754  -0.6586543   1.51565604  0.707497   -0.2426008   0.06039312]
#  [-0.74387955 -0.06638045 -0.87390715 -0.66707622  0.78632998 -1.03615034]]
#
# [[ 1.96755992 -0.95297516  2.1831636   1.05568928  1.29386139  0.89739853
#    0.17313302  0.5384962   0.16166569  0.92176764]
#  [-1.49605658 -0.46209185 -0.32505144 -1.54145575  0.13001676  0.56783193
#    0.47006383 -0.93555969  0.3777754  -0.6586543 ]
#  [ 1.51565604  0.707497   -0.2426008   0.06039312 -0.74387955 -0.06638045
#   -0.87390715 -0.66707622  0.78632998 -1.03615034]]
#
# [[-0.14888716 -2.63979943]
#  [-0.10779305  1.02149489]
#  [ 1.22243286  0.73595864]
#  [ 1.66654627 -1.42209505]
#  [ 0.94199019  0.40040102]
#  [-0.14342312 -1.03527207]]
# [[-0.14888716 -0.10779305  1.22243286  1.66654627  0.94199019 -0.14342312]
#  [-2.63979943  1.02149489  0.73595864 -1.42209505  0.40040102 -1.03527207]]

# %%
import numpy as np



data1 = np.array([10**(-4+i/100) for i in range(801)]) # 저장하는 데이터 10^-4~10^4
temp = []
for i in range(801):
    for j in range(i,801):
        temp.append([data1[i],data1[j],data1[i]+data1[j],data1[i]*data1[j]])

data2 = np.array(temp)
print(data2)

#np.save('my_data.npy', data2) # numpy.ndarray 저장. @파일명, @값



#data3 = np.load('my_data.npy') # 데이터 로드. @파일명
# Out:
# [[1.00000000e-04 1.00000000e-04 2.00000000e-04 1.00000000e-08]
#  [1.00000000e-04 1.02329299e-04 2.02329299e-04 1.02329299e-08]
#  [1.00000000e-04 1.04712855e-04 2.04712855e-04 1.04712855e-08]
#  ...
#  [9.77237221e+03 9.77237221e+03 1.95447444e+04 9.54992586e+07]
#  [9.77237221e+03 1.00000000e+04 1.97723722e+04 9.77237221e+07]
#  [1.00000000e+04 1.00000000e+04 2.00000000e+04 1.00000000e+08]]
